# %%
#colors in set1 but not in set2
set1=set(input("Enter colors in set1:").split())
set2=set(input("Enter colors in set2:").split())
print("The colors in set1 but not in set2:",set1.difference(set2))
# Out:
# Enter colors in set1: pink green yellow purple
# Enter colors in set2: red green blue pink
# The colors in set1 but not in set2: {'purple', 'yellow'}

# %%
#display all the colors in two sets
s1=set(input("Enter the colors in se1:").split())
s2=set(input("Enter the colors in se2:").split())
print("The colors in both sets are:",s1.union(s2))
# Out:
# Enter the colors in se1: green yellow orange blue
# Enter the colors in se2: orange red blue purple
# The colors in both sets are: {'yellow', 'blue', 'red', 'purple', 'orange', 'green'}

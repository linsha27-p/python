# %%
#colors in set 1 but not in set 2
set1=set(input("Enter colors in set1:").split())
set2=set(input("Enter colors in set2:").split())
print("Set 1:",set1)
print("Set 2:",set2)
print("The colors in set1 but not in set2:",set1.difference(set2))
# Out:
# Enter colors in set1: green yellow orange blue
# Enter colors in set2: red blue green pink
# Set 1: {'orange', 'blue', 'green', 'yellow'}
# Set 2: {'red', 'blue', 'pink', 'green'}
# The colors in set1 but not in set2: {'orange', 'yellow'}

# %%
#display all the colors in two sets
s1=set(input("Enter colors in set1:").split())
s2=set(input("Enter colors in set2:").split())
print("Set 1:",s1)
print("Set 2:",s2)
print("The colors in both srts are:",s1.union(s2))
# Out:
# Enter colors in set1: green yellow orange blue
# Enter colors in set2: red pink yellow green
# Set 1: {'orange', 'blue', 'green', 'yellow'}
# Set 2: {'red', 'pink', 'green', 'yellow'}
# The colors in both srts are: {'pink', 'orange', 'green', 'yellow', 'blue', 'red'}

# %%
#get 3rd element from first and 3rd element from last of a tuple
n=input("Enter the numbers separated by commas:")
tuples=tuple(map(int,n.split(",")))
print("Tuple is:",tuples)
print("3rd element from first is",tuples[2])
print("3rd element from last is",tuples[-3])
# Out:
# Enter the numbers separated by commas: 10,40,80,90,40,60,70
# Tuple is: (10, 40, 80, 90, 40, 60, 70)
# 3rd element from first is 80
# 3rd element from last is 40

# %%
#generate a tuple and find its  average
number=input("Enter the number:")
tuples=tuple(map(int,number.split(",")))
print("Tuple is:",tuples)
print("averageis:",sum(tuples)/len(tuples))
# Out:
# Enter the number: 40,50,40,90,10,70,60
# Tuple is: (40, 50, 40, 90, 10, 70, 60)
# averageis: 51.42857142857143

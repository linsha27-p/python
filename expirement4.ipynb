# %%
#display first and last colors
color=input("enter colors:\n")
lists=color.split(",")
print("first color:",lists[0],"second color:",lists[-1])
# Out:
# enter colors:
#  red,blue,yellow,pink
# first color: red second color: pink

# %%
#print file extension
filename=input("enter the filename:")
extension=filename.split(".")[-1]
print("extension:",extension)
# Out:
# enter the filename: linsha.txt
# extension: txt

# %%
#list the number and sum
number=input("enter the numbers:")
lists=list(map(int,number.split(",")))
print("list is:",lists)
print("sum is:",sum(lists))
# Out:
# enter the numbers: 1,2,3,4,5
# list is: [1, 2, 3, 4, 5]
# sum is: 15

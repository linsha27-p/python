# %%
#accept 5 students name and roll numbers
roll=input("Enter roll(Space separated):").split()
name=input("Enter name(Space separated):").split()
mydict=dict(zip(roll,name))
print("ascending order:",dict(sorted(mydict.items())))
print("descending order:",dict(sorted(mydict.items(),reverse=True)))
# Out:
# Enter roll(Space separated): 1 2 3  4 5 6
# Enter name(Space separated): linsha bisma anamika sumu rasha riyana
# ascending order: {'1': 'linsha', '2': 'bisma', '3': 'anamika', '4': 'sumu', '5': 'rasha', '6': 'riyana'}
# descending order: {'6': 'riyana', '5': 'rasha', '4': 'sumu', '3': 'anamika', '2': 'bisma', '1': 'linsha'}

# %%
#merge two dictinaries using update()
dict1={1:"lin",2:"sumu",3:"mika"}
dict2={4:"riya",5:"bis"}
dict1.update(dict2)
print("merged dictionaries:",dict1)
# Out:
# merged dictionaries: {1: 'lin', 2: 'sumu', 3: 'mika', 4: 'riya', 5: 'bis'}

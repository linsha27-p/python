# %%
#sort dictionary ascenting or descending order
roll=input("Enter Roll(space separated):").split()
name=input("Enter Name(space separated):").split()
mydict=dict(zip(roll,name))
print("Original dictionary:",mydict)
print("Ascending order:",dict(sorted(mydict.items())))
print("descending order:",dict(sorted(mydict.items(),reverse=True)))
# Out:
# Enter Roll(space separated): 2 3 4 5 1
# Enter Name(space separated): anu minu manu lulu sonu
# Original dictionary: {'2': 'anu', '3': 'minu', '4': 'manu', '5': 'lulu', '1': 'sonu'}
# Ascending order: {'1': 'sonu', '2': 'anu', '3': 'minu', '4': 'manu', '5': 'lulu'}
# descending order: {'5': 'lulu', '4': 'manu', '3': 'minu', '2': 'anu', '1': 'sonu'}

# %%
#merge two dictinaries using update()
dict1={1:"bisma",2:"rasha",3:"anamika"}
dict2={4:"linsha",5:"anamika"}
print("original dictionary 1:",dict1)
print("original dictinary 2:",dict2)
dict1.update(dict2)
print("Merged dictionaries:",dict1)
# Out:
# original dictionary 1: {1: 'bisma', 2: 'rasha', 3: 'anamika'}
# original dictinary 2: {4: 'linsha', 5: 'anamika'}
# Merged dictionaries: {1: 'bisma', 2: 'rasha', 3: 'anamika', 4: 'linsha', 5: 'anamika'}
